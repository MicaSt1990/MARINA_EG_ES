# %%
# --- IMPORTS ---
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
from pathlib import Path
from matplotlib import rcParams

print("[INFO] Libraries loaded successfully")
# Out:
# [INFO] Libraries loaded successfully

# %%
# --- CONFIGURATION & FONT SETUP ---
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']

BASE_DIR = Path("")  # current working directory

SPI_FILE = BASE_DIR / "SPI_1981_2024.nc"
MASK_FILE = BASE_DIR / "mask.nc"

OUT_DIR = BASE_DIR / "Analisis_Ranking_Series"
OUT_DIR.mkdir(parents=True, exist_ok=True)

print("[INFO] Paths configured")
print("SPI file:", SPI_FILE)
print("Mask file:", MASK_FILE)
print("Output dir:", OUT_DIR)
# Out:
# [INFO] Paths configured
# SPI file: SPI_1981_2024.nc
# Mask file: mask.nc
# Output dir: Analisis_Ranking_Series

# %%
# --- THRESHOLDS & TEMPORAL SETUP ---
THR_MOD = -0.84
THR_EXT = -1.28
THR_VEX = -1.65

months_idx = [1, 4, 7, 10]

season_names = {
    1: 'Winter (Feb)',
    4: 'Spring (May)',
    7: 'Summer (Aug)',
    10: 'Autumn (Nov)'
}

start_year, end_year = 1981, 2024

print("[INFO] Configuration ready")
# Out:
# [INFO] Configuration ready
